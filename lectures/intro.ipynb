# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/tulane-intro-ai-engineering/blob/main/labs/lab01_hello_api.ipynb)

# %% [markdown]
# test
